# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from keras.layers import Conv2D, MaxPooling2D, Flatten, BatchNormalization, Dropout, Dense, Activation, GlobalAveragePooling2D, Input

from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential

from sklearn.model_selection import train_test_split

from keras.utils import to_categorical
import keras.backend as K

from keras.layers.convolutional import Convolution2D, MaxPooling2D, ZeroPadding2D
from keras.optimizers import SGD

from keras import optimizers
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

from numpy import array
from numpy import argmax
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
# Out:
# Using TensorFlow backend.

# %%
ls
# Out:
# drive/  sample_data/

# %%
data_path = '/content/drive/My Drive/petrography/numpy_array_folder/'

# %%
x_images = np.load(data_path + "/x_images_px2.npz")
x = x_images['arr_0']

y_label = np.load(data_path + "/y_label_px2.npz")
y = y_label['arr_0']

# %%
x[450]
# Out:
# array([[[105.,  98.,  88., ..., 145., 190., 195.],
#         [199., 240., 241., ..., 160., 155., 146.],
#         [139., 133., 140., ..., 144., 130., 129.],
#         ...,
#         [ 66.,  69.,  77., ..., 165., 175., 167.],
#         [116., 115., 120., ..., 151.,  92.,  90.],
#         [ 91.,  61.,  56., ...,  85.,  82.,  86.]],
#
#        [[ 82.,  83., 128., ..., 144., 144., 146.],
#         [137., 138., 143., ..., 164., 123., 121.],
#         [122.,   9.,   5., ...,  57.,  53.,  94.],
#         ...,
#         [201., 178., 182., ..., 229., 233., 204.],
#         [205., 207., 144., ..., 144., 135., 126.],
#         [ 77.,  72.,  69., ..., 157., 199., 201.]],
#
#        [[200., 165., 169., ..., 154., 159., 199.],
#         [200., 204., 221., ..., 106.,  95.,  89.],
#         [102.,  98.,  89., ..., 130., 147., 146.],
#         ...,
#         [101.,  92.,  93., ...,  28.,   0.,   0.],
#         [  9.,  47.,  46., ..., 169., 161.,  66.],
#         [ 64.,  52.,  33., ...,  92.,  86.,  96.]]], dtype=float32)

# %%
y
# Out:
# array(['p', 'p', 'p', ..., 'x', 'x', 'x'], dtype='<U1')

# %%
# Split into training, validation, and test sets (80/10/10)

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=33)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, test_size=0.5, random_state=33)

print("Train set size: {0}, Val set size: {1}, Test set size: {2}".format(len(X_train), len(X_val), len(X_test)))
# print("Train set size: {0}, Test set size: {1}".format(len(X_train), len(X_test)))
# Out:
# Train set size: 3840, Val set size: 480, Test set size: 480

# %%
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_val = X_val.astype('float32')
X_train /= 255.0
X_test /= 255.0
X_val /= 255.0

# %%
X_train_reshape = X_train.reshape(-1,224,224,3)
X_val_reshape = X_val.reshape(-1,224,224,3)
X_test_reshape = X_test.reshape(-1,224,224,3)

# %%
# integer encode
label_encoder = LabelEncoder()
y_train_integer_encoded = label_encoder.fit_transform(y_train)
y_val_integer_encoded = label_encoder.fit_transform(y_val)
y_test_integer_encoded = label_encoder.fit_transform(y_test)

# binary encode
onehot_encoder = OneHotEncoder(sparse=False)

y_train_integer_encoded = y_train_integer_encoded.reshape(len(y_train_integer_encoded), 1)
y_train_onehot = onehot_encoder.fit_transform(y_train_integer_encoded)

y_val_integer_encoded = y_val_integer_encoded.reshape(len(y_val_integer_encoded), 1)
y_val_onehot = onehot_encoder.fit_transform(y_val_integer_encoded)

y_test_integer_encoded = y_test_integer_encoded.reshape(len(y_test_integer_encoded), 1)
y_test_onehot = onehot_encoder.fit_transform(y_test_integer_encoded)

print("y: Train set shape: {0}, Val set shape: {1}, Test set shape: {2}".format(y_train_onehot.shape, y_val_onehot.shape, y_val_onehot.shape))
# Out:
# y: Train set shape: (3840, 2), Val set shape: (480, 2), Test set shape: (480, 2)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.6/dist-packages/sklearn/preprocessing/_encoders.py:368: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)

# %%
y_train_integer_encoded.shape
# Out:
# (3840, 1)

# %%
y_val_integer_encoded.shape
# Out:
# (480, 1)

# %%
y_test_integer_encoded.shape
# Out:
# (480, 1)

# %%
X_train.shape
# Out:
# (3840, 3, 224, 224)

# %%
X_val.shape
# Out:
# (480, 3, 224, 224)

# %%
X_test.shape
# Out:
# (480, 3, 224, 224)

# %%
X_train_reshape.shape
# Out:
# (3840, 224, 224, 3)

# %%
X_val_reshape.shape
# Out:
# (480, 224, 224, 3)

# %%
X_test_reshape.shape
# Out:
# (480, 224, 224, 3)

# %%
X_train[450]
# Out:
# array([[[0.06666667, 0.01176471, 0.00784314, ..., 0.9254902 ,
#          0.85882354, 0.90588236],
#         [0.90588236, 0.6784314 , 0.7137255 , ..., 0.23137255,
#          0.25490198, 0.38431373],
#         [0.41960785, 0.45490196, 0.14117648, ..., 0.0627451 ,
#          0.05882353, 0.04313726],
#         ...,
#         [0.8       , 0.80784315, 0.5254902 , ..., 0.21568628,
#          0.22745098, 0.24705882],
#         [0.24313726, 0.30980393, 0.34901962, ..., 0.03921569,
#          0.03529412, 0.02745098],
#         [0.03921569, 0.03137255, 0.02352941, ..., 0.5568628 ,
#          0.5568628 , 0.7647059 ]],
#
#        [[0.8039216 , 0.8117647 , 0.5137255 , ..., 0.36078432,
#          0.40392157, 0.4117647 ],
#         [0.38431373, 0.4509804 , 0.5137255 , ..., 0.02745098,
#          0.03137255, 0.02352941],
#         [0.03529412, 0.02352941, 0.01568628, ..., 0.12156863,
#          0.11764706, 0.43137255],
#         ...,
#         [0.18431373, 0.84313726, 0.827451  , ..., 0.6745098 ,
#          0.654902  , 0.7647059 ],
#         [0.7921569 , 0.7647059 , 0.7764706 , ..., 0.1882353 ,
#          0.13725491, 0.11372549],
#         [0.7058824 , 0.7607843 , 0.7607843 , ..., 0.1254902 ,
#          0.14509805, 0.12156863]],
#
#        [[0.13725491, 0.654902  , 0.6313726 , ..., 0.73333335,
#          0.72156864, 0.78039217],
#         [0.8039216 , 0.7882353 , 0.7137255 , ..., 0.07058824,
#          0.03529412, 0.04705882],
#         [0.5019608 , 0.52156866, 0.5372549 , ..., 0.25882354,
#          0.13333334, 0.11372549],
#         ...,
#         [0.09803922, 0.09019608, 0.10980392, ..., 0.9607843 ,
#          0.94509804, 0.92941177],
#         [0.88235295, 0.64705884, 0.6431373 , ..., 0.02745098,
#          0.01176471, 0.01568628],
#         [0.01568628, 0.00784314, 0.01568628, ..., 0.3882353 ,
#          0.42745098, 0.4627451 ]]], dtype=float32)

# %%
X_train_reshape[450]
# Out:
# array([[[0.06666667, 0.01176471, 0.00784314],
#         [0.12941177, 0.09019608, 0.12156863],
#         [0.02352941, 0.01960784, 0.07450981],
#         ...,
#         [0.09803922, 0.08235294, 0.07843138],
#         [0.0627451 , 0.04705882, 0.03529412],
#         [0.0627451 , 0.05882353, 0.04313726]],
#
#        [[0.34117648, 0.28627452, 0.2509804 ],
#         [0.25882354, 0.21568628, 0.20784314],
#         [0.05490196, 0.02745098, 0.05490196],
#         ...,
#         [0.05490196, 0.04705882, 0.05882353],
#         [0.0627451 , 0.05490196, 0.05882353],
#         [0.05098039, 0.05098039, 0.05098039]],
#
#        [[0.47058824, 0.40784314, 0.34901962],
#         [0.29803923, 0.24313726, 0.20784314],
#         [0.12941177, 0.07450981, 0.07058824],
#         ...,
#         [0.05490196, 0.04705882, 0.05882353],
#         [0.05098039, 0.05098039, 0.05882353],
#         [0.04705882, 0.03921569, 0.04313726]],
#
#        ...,
#
#        [[0.14509805, 0.16862746, 0.15294118],
#         [0.14509805, 0.18431373, 0.19215687],
#         [0.2627451 , 0.3137255 , 0.34901962],
#         ...,
#         [0.2509804 , 0.30588236, 0.30980393],
#         [0.32941177, 0.36862746, 0.3764706 ],
#         [0.41568628, 0.42745098, 0.45490196]],
#
#        [[0.11372549, 0.12941177, 0.13333334],
#         [0.1254902 , 0.15294118, 0.1764706 ],
#         [0.4509804 , 0.4862745 , 0.52156866],
#         ...,
#         [0.14117648, 0.18431373, 0.20784314],
#         [0.30980393, 0.3529412 , 0.3764706 ],
#         [0.3764706 , 0.4117647 , 0.4392157 ]],
#
#        [[0.09803922, 0.09019608, 0.10980392],
#         [0.08235294, 0.09411765, 0.12156863],
#         [0.6039216 , 0.6392157 , 0.6666667 ],
#         ...,
#         [0.30588236, 0.33333334, 0.37254903],
#         [0.41568628, 0.45490196, 0.49019608],
#         [0.3882353 , 0.42745098, 0.4627451 ]]], dtype=float32)

# %%
y_train_integer_encoded[450]
# Out:
# array([1])

# %%
plt.imshow(X_train_reshape[450])
plt.show()

# %%
K.set_image_data_format('channels_last')
K.image_data_format()
# Out:
# 'channels_last'

# %% [markdown]
# **VGG16**

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import os
from urllib.request import urlopen,urlretrieve
from PIL import Image
from tqdm import tqdm_notebook
# %matplotlib inline
from sklearn.utils import shuffle
import cv2

from keras.models import load_model
from sklearn.datasets import load_files   
from keras.utils import np_utils
from glob import glob
from keras import applications
from keras.preprocessing.image import ImageDataGenerator 
from keras import optimizers
from keras.models import Sequential,Model,load_model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D,GlobalAveragePooling2D
from keras.callbacks import TensorBoard,ReduceLROnPlateau,ModelCheckpoint

from keras.applications.vgg16 import VGG16
from keras.applications.resnet50 import ResNet50
from keras.applications.vgg19 import VGG19
from keras.applications.inception_v3 import InceptionV3

# %%
img_height,img_width = 224, 224 
num_classes = 1

base_model = VGG16(weights= 'imagenet', include_top=False, input_shape= (img_height,img_width,3))

x = base_model.output

x = Flatten(name='flatten')(x)
x = Dense(4096, activation='relu', name='fc1')(x)
x = Dense(4096, activation='relu', name='fc2')(x)

predictions = Dense(num_classes, activation= 'sigmoid', name='fc3')(x)
model = Model(inputs = base_model.input, outputs = predictions)

# %%
adam = optimizers.Adam(lr=0.0001)
model.compile(optimizer = adam,
              loss = 'binary_crossentropy',
              metrics = ['accuracy'])

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# fc3 (Dense)                  (None, 1)                 4097
# =================================================================
# Total params: 134,264,641
# Trainable params: 134,264,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
checkpointer = ModelCheckpoint(filepath = '/content/drive/My Drive/petrography/model/weights_vgg16_px2.hdf5',
                               verbose=1, save_best_only=True)

# %%
from tensorboardcolab import *
tbc = TensorBoardColab()
# Out:
# Wait for 8 seconds...
# TensorBoard link:
# https://034ecc9a.ngrok.io

# %%
history = model.fit(x = X_train_reshape, y = y_train_integer_encoded, batch_size=32,
                    epochs=50, 
                    validation_data=(X_val_reshape, y_val_integer_encoded), shuffle=True,
                    callbacks=[checkpointer, TensorBoardColabCallback(tbc)])
# Out:
# Train on 3840 samples, validate on 480 samples
# Epoch 1/50
# 3840/3840 [==============================] - 125s 32ms/step - loss: 0.2057 - acc: 0.9198 - val_loss: 0.0992 - val_acc: 0.9792
#
# Epoch 00001: val_loss improved from 0.11417 to 0.09917, saving model to /content/drive/My Drive/petrography/model/weights_vgg16_px2.hdf5
# Epoch 2/50
# 3840/3840 [==============================] - 124s 32ms/step - loss: 0.1119 - acc: 0.9604 - val_loss: 0.0520 - val_acc: 0.9729
#
# Epoch 00002: val_loss improved from 0.09917 to 0.05200, saving model to /content/drive/My Drive/petrography/model/weights_vgg16_px2.hdf5
# Epoch 3/50
# 3840/3840 [==============================] - 124s 32ms/step - loss: 0.0945 - acc: 0.9659 - val_loss: 0.1381 - val_acc: 0.9542
#
# Epoch 00003: val_loss did not improve from 0.05200
# Epoch 4/50
# 3840/3840 [==============================] - 124s 32ms/step - loss: 0.1205 - acc: 0.9576 - val_loss: 0.0987 - val_acc: 0.9625
#
# Epoch 00004: val_loss did not improve from 0.05200
# Epoch 5/50
# 3840/3840 [==============================] - 124s 32ms/step - loss: 0.0643 - acc: 0.9755 - val_loss: 0.0220 - val_acc: 0.9917
#
# Epoch 00005: val_loss improved from 0.05200 to 0.02197, saving model to /content/drive/My Drive/petrography/model/weights_vgg16_px2.hdf5
# Epoch 6/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0561 - acc: 0.9789 - val_loss: 0.0393 - val_acc: 0.9812
#
# Epoch 00006: val_loss did not improve from 0.02197
# Epoch 7/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0442 - acc: 0.9820 - val_loss: 0.0344 - val_acc: 0.9792
#
# Epoch 00007: val_loss did not improve from 0.02197
# Epoch 8/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0448 - acc: 0.9815 - val_loss: 0.0196 - val_acc: 0.9917
#
# Epoch 00008: val_loss improved from 0.02197 to 0.01956, saving model to /content/drive/My Drive/petrography/model/weights_vgg16_px2.hdf5
# Epoch 9/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0418 - acc: 0.9826 - val_loss: 0.0336 - val_acc: 0.9812
#
# Epoch 00009: val_loss did not improve from 0.01956
# Epoch 10/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0692 - acc: 0.9747 - val_loss: 0.0497 - val_acc: 0.9812
#
# Epoch 00010: val_loss did not improve from 0.01956
# Epoch 11/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0312 - acc: 0.9872 - val_loss: 0.0249 - val_acc: 0.9896
#
# Epoch 00011: val_loss did not improve from 0.01956
# Epoch 12/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0364 - acc: 0.9865 - val_loss: 0.0160 - val_acc: 0.9938
#
# Epoch 00012: val_loss improved from 0.01956 to 0.01597, saving model to /content/drive/My Drive/petrography/model/weights_vgg16_px2.hdf5
# Epoch 13/50
# 3840/3840 [==============================] - 122s 32ms/step - loss: 0.0386 - acc: 0.9862 - val_loss: 0.0315 - val_acc: 0.9833
#
# Epoch 00013: val_loss did not improve from 0.01597
# Epoch 14/50
# 3840/3840 [==============================] - 122s 32ms/step - loss: 0.0224 - acc: 0.9904 - val_loss: 0.0184 - val_acc: 0.9917
#
# Epoch 00014: val_loss did not improve from 0.01597
# Epoch 15/50
# 3840/3840 [==============================] - 122s 32ms/step - loss: 0.0198 - acc: 0.9924 - val_loss: 0.0244 - val_acc: 0.9896
#
# Epoch 00015: val_loss did not improve from 0.01597
# Epoch 16/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0410 - acc: 0.9872 - val_loss: 0.0274 - val_acc: 0.9812
#
# Epoch 00016: val_loss did not improve from 0.01597
# Epoch 17/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0205 - acc: 0.9922 - val_loss: 0.0231 - val_acc: 0.9917
#
# Epoch 00017: val_loss did not improve from 0.01597
# Epoch 18/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0600 - acc: 0.9805 - val_loss: 0.0135 - val_acc: 0.9958
#
# Epoch 00018: val_loss improved from 0.01597 to 0.01350, saving model to /content/drive/My Drive/petrography/model/weights_vgg16_px2.hdf5
# Epoch 19/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0584 - acc: 0.9841 - val_loss: 0.0941 - val_acc: 0.9729
#
# Epoch 00019: val_loss did not improve from 0.01350
# Epoch 20/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0425 - acc: 0.9846 - val_loss: 0.0163 - val_acc: 0.9958
#
# Epoch 00020: val_loss did not improve from 0.01350
# Epoch 21/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0239 - acc: 0.9919 - val_loss: 0.0228 - val_acc: 0.9917
#
# Epoch 00021: val_loss did not improve from 0.01350
# Epoch 22/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0243 - acc: 0.9904 - val_loss: 0.0067 - val_acc: 0.9958
#
# Epoch 00022: val_loss improved from 0.01350 to 0.00672, saving model to /content/drive/My Drive/petrography/model/weights_vgg16_px2.hdf5
# Epoch 23/50
# 3840/3840 [==============================] - 122s 32ms/step - loss: 0.0042 - acc: 0.9987 - val_loss: 0.0082 - val_acc: 0.9979
#
# Epoch 00023: val_loss did not improve from 0.00672
# Epoch 24/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0404 - acc: 0.9870 - val_loss: 0.0160 - val_acc: 0.9938
#
# Epoch 00024: val_loss did not improve from 0.00672
# Epoch 25/50
# 3840/3840 [==============================] - 122s 32ms/step - loss: 0.0125 - acc: 0.9961 - val_loss: 0.0426 - val_acc: 0.9875
#
# Epoch 00025: val_loss did not improve from 0.00672
# Epoch 26/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0249 - acc: 0.9911 - val_loss: 0.0039 - val_acc: 1.0000
#
# Epoch 00026: val_loss improved from 0.00672 to 0.00393, saving model to /content/drive/My Drive/petrography/model/weights_vgg16_px2.hdf5
# Epoch 27/50
# 3840/3840 [==============================] - 122s 32ms/step - loss: 0.0215 - acc: 0.9927 - val_loss: 0.0467 - val_acc: 0.9833
#
# Epoch 00027: val_loss did not improve from 0.00393
# Epoch 28/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0235 - acc: 0.9911 - val_loss: 0.0188 - val_acc: 0.9938
#
# Epoch 00028: val_loss did not improve from 0.00393
# Epoch 29/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0195 - acc: 0.9938 - val_loss: 0.0411 - val_acc: 0.9875
#
# Epoch 00029: val_loss did not improve from 0.00393
# Epoch 30/50
# 3840/3840 [==============================] - 123s 32ms/step - loss: 0.0231 - acc: 0.9909 - val_loss: 0.0138 - val_acc: 0.9875
#
# Epoch 00030: val_loss did not improve from 0.00393
# Epoch 31/50
# 3840/3840 [==============================] - 121s 32ms/step - loss: 0.0147 - acc: 0.9958 - val_loss: 0.0223 - val_acc: 0.9896
#
# Epoch 00031: val_loss did not improve from 0.00393
# Epoch 32/50
# 3840/3840 [==============================] - 122s 32ms/step - loss: 0.0077 - acc: 0.9971 - val_loss: 0.0166 - val_acc: 0.9938
#
# Epoch 00032: val_loss did not improve from 0.00393
# Epoch 33/50
# 3840/3840 [==============================] - 122s 32ms/step - loss: 0.0091 - acc: 0.9969 - val_loss: 0.0236 - val_acc: 0.9958
#
# Epoch 00033: val_loss did not improve from 0.00393
# Epoch 34/50
# 3840/3840 [==============================] - 122s 32ms/step - loss: 0.0056 - acc: 0.9979 - val_loss: 0.0073 - val_acc: 0.9979
#
# Epoch 00034: val_loss did not improve from 0.00393
# Epoch 35/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 8.6074e-05 - acc: 1.0000 - val_loss: 0.0183 - val_acc: 0.9938
#
# Epoch 00035: val_loss did not improve from 0.00393
# Epoch 36/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 2.5816e-05 - acc: 1.0000 - val_loss: 0.0173 - val_acc: 0.9958
#
# Epoch 00036: val_loss did not improve from 0.00393
# Epoch 37/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 6.7166e-06 - acc: 1.0000 - val_loss: 0.0216 - val_acc: 0.9958
#
# Epoch 00037: val_loss did not improve from 0.00393
# Epoch 38/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 3.3702e-06 - acc: 1.0000 - val_loss: 0.0247 - val_acc: 0.9958
#
# Epoch 00038: val_loss did not improve from 0.00393
# Epoch 39/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 1.8655e-06 - acc: 1.0000 - val_loss: 0.0276 - val_acc: 0.9958
#
# Epoch 00039: val_loss did not improve from 0.00393
# Epoch 40/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 1.2043e-06 - acc: 1.0000 - val_loss: 0.0295 - val_acc: 0.9958
#
# Epoch 00040: val_loss did not improve from 0.00393
# Epoch 41/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 8.3932e-07 - acc: 1.0000 - val_loss: 0.0295 - val_acc: 0.9958
#
# Epoch 00041: val_loss did not improve from 0.00393
# Epoch 42/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 6.5074e-07 - acc: 1.0000 - val_loss: 0.0310 - val_acc: 0.9958
#
# Epoch 00042: val_loss did not improve from 0.00393
# Epoch 43/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 5.1490e-07 - acc: 1.0000 - val_loss: 0.0334 - val_acc: 0.9958
#
# Epoch 00043: val_loss did not improve from 0.00393
# Epoch 44/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 4.1700e-07 - acc: 1.0000 - val_loss: 0.0338 - val_acc: 0.9958
#
# Epoch 00044: val_loss did not improve from 0.00393
# Epoch 45/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 3.6371e-07 - acc: 1.0000 - val_loss: 0.0350 - val_acc: 0.9958
#
# Epoch 00045: val_loss did not improve from 0.00393
# Epoch 46/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 3.1990e-07 - acc: 1.0000 - val_loss: 0.0365 - val_acc: 0.9958
#
# Epoch 00046: val_loss did not improve from 0.00393
# Epoch 47/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 2.9215e-07 - acc: 1.0000 - val_loss: 0.0371 - val_acc: 0.9958
#
# Epoch 00047: val_loss did not improve from 0.00393
# Epoch 48/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 2.6599e-07 - acc: 1.0000 - val_loss: 0.0367 - val_acc: 0.9958
#
# Epoch 00048: val_loss did not improve from 0.00393
# Epoch 49/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 2.4996e-07 - acc: 1.0000 - val_loss: 0.0377 - val_acc: 0.9958
#
# Epoch 00049: val_loss did not improve from 0.00393
# Epoch 50/50
# 3840/3840 [==============================] - 121s 31ms/step - loss: 2.3198e-07 - acc: 1.0000 - val_loss: 0.0376 - val_acc: 0.9958
#
# Epoch 00050: val_loss did not improve from 0.00393

# %%
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'blue', label='Training acc')
plt.plot(epochs, val_acc, 'red', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()
plt.plot(epochs, loss, 'blue', label='Training loss')
plt.plot(epochs, val_loss, 'red', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
result = model.evaluate(X_test_reshape, y_test_integer_encoded)
print ("Loss = " + str(result[0]))
print ("Test Accuracy = " + str(result[1]))
# Out:
# 480/480 [==============================] - 5s 10ms/step
# Loss = 0.008534595199143761
# Test Accuracy = 0.9958333333333333

# %%
pred = model.predict(X_test_reshape, verbose=1)
# Out:
# 480/480 [==============================] - 5s 10ms/step

# %%
result
# Out:
# [0.008534595199143761, 0.9958333333333333]

# %%
pred
# Out:
# array([[1.0000000e+00, 3.8730174e-16, 5.6427448e-13, 1.9647233e-20,
#         2.1130235e-29, 8.1082105e-36],
#        [4.0199180e-16, 3.7578871e-29, 1.8033899e-15, 1.0000000e+00,
#         2.1819145e-19, 1.6773305e-24],
#        [1.0000000e+00, 9.9837624e-16, 5.5859544e-18, 1.2348691e-21,
#         2.0579182e-30, 0.0000000e+00],
#        ...,
#        [1.0746622e-22, 2.3012090e-23, 1.4979918e-07, 4.0687800e-11,
#         3.3081811e-17, 9.9999988e-01],
#        [1.0571216e-11, 1.0539341e-12, 1.0000000e+00, 1.0960465e-14,
#         9.4909066e-18, 4.4907212e-13],
#        [1.6166282e-11, 1.8430342e-12, 9.9192238e-01, 5.6206716e-08,
#         1.6244226e-12, 8.0776261e-03]], dtype=float32)

# %%
y_train_pred = model.predict(X_train_reshape).ravel()
y_test_pred = model.predict(X_test_reshape).ravel()

# %%
y_train_pred_class = model.predict(X_train_reshape)
y_test_pred_class = model.predict(X_test_reshape)

# %%
y_train_pred
# Out:
# array([5.2114653e-20, 3.4068326e-10, 1.1582024e-16, ..., 1.0000000e+00,
#        0.0000000e+00, 0.0000000e+00], dtype=float32)

# %%
y_train_pred_class
# Out:
# array([[5.2114653e-20, 3.4068326e-10, 1.1582024e-16, 1.7621070e-13,
#         1.0000000e+00, 2.7613523e-11],
#        [3.6612439e-13, 2.6959423e-17, 1.0000000e+00, 3.5264612e-17,
#         9.4189285e-23, 4.1861011e-16],
#        [1.0000000e+00, 3.7539078e-12, 2.4252692e-11, 9.5377720e-16,
#         1.4971742e-23, 1.7879854e-29],
#        ...,
#        [1.7473305e-32, 0.0000000e+00, 1.1563317e-29, 1.0000000e+00,
#         8.0183380e-20, 2.3972865e-20],
#        [1.0000000e+00, 3.4868647e-14, 1.7176391e-15, 2.0148029e-19,
#         7.3866395e-28, 4.0146167e-38],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)

# %%
y_test_pred
# Out:
# array([1.0000000e+00, 3.8730174e-16, 5.6427448e-13, ..., 5.6206716e-08,
#        1.6244226e-12, 8.0776261e-03], dtype=float32)

# %%
y_train_pred_class
# Out:
# array([[5.2114653e-20, 3.4068326e-10, 1.1582024e-16, 1.7621070e-13,
#         1.0000000e+00, 2.7613523e-11],
#        [3.6612439e-13, 2.6959423e-17, 1.0000000e+00, 3.5264612e-17,
#         9.4189285e-23, 4.1861011e-16],
#        [1.0000000e+00, 3.7539078e-12, 2.4252692e-11, 9.5377720e-16,
#         1.4971742e-23, 1.7879854e-29],
#        ...,
#        [1.7473305e-32, 0.0000000e+00, 1.1563317e-29, 1.0000000e+00,
#         8.0183380e-20, 2.3972865e-20],
#        [1.0000000e+00, 3.4868647e-14, 1.7176391e-15, 2.0148029e-19,
#         7.3866395e-28, 4.0146167e-38],
#        [0.0000000e+00, 0.0000000e+00, 0.0000000e+00, 1.0000000e+00,
#         0.0000000e+00, 0.0000000e+00]], dtype=float32)
